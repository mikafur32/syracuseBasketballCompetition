# %% [markdown]
# # Logistic Regression Voting Model

# %% [markdown]
# ## 00. TODO

# %% [markdown]
# 1. Generate predictions for all
# 2. Voting Classifier

# %% [markdown]
# ## 0. Imports

# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn as sk
assert sk.__version__ >= "0.20"

# XGBoost Import
import xgboost as xgb
xgb.set_config(verbosity = 2)
# assert xgb.get_config["verbosity"] == 0

# Common imports
import numpy as np
import os
import pandas as pd
import seaborn as sns

# to make this notebook's output stable across runs
np.random.seed(0)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

from IPython.display import display, HTML

pd.set_option('display.max_columns', None)

# Get current directory of file (so filesystem should work regardless of user machine)
print(os.getcwd())
parent = os.pardir
print(parent)

# Read in data from sources
play_by_play_path = os.path.join(parent, 'Data')
play_by_play_path = os.path.join(play_by_play_path, 'syracuse_gsw_basic_pbp.csv')
play_by_play_df = pd.read_csv(play_by_play_path)

results_path = os.path.join(parent, 'Data')
results_path = os.path.join(results_path, "syracuse_gsw_basic_results.csv")
game_results_df = pd.read_csv(results_path)

game_data_master_path = os.path.join(parent, 'Data')
game_data_master_path = os.path.join(game_data_master_path, 'game_data_master.csv')
game_data_master = pd.read_csv(game_data_master_path)



# Reset indices
play_by_play_df.set_index('id', inplace= True)
game_results_df.set_index('id', inplace= True)
display(play_by_play_df.head(2))


import warnings
from sklearn.exceptions import DataConversionWarning
warnings.filterwarnings(action='ignore', category=DataConversionWarning)
warnings.filterwarnings(action='ignore', category=FutureWarning)
# Out:
# C:\Users\perso\anaconda3\envs\Shark_env\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# C:\Users\perso\Documents\GitHub\syracuseBasketballCompetition\Player Models
# ..
#       season     season_type  nba_game_id home away   game_date  quarter  \
# id
# 1219    2021  Regular Season     22100002  LAL  GSW  10/19/2021        1
# 1227    2021  Regular Season     22100002  LAL  GSW  10/19/2021        1
#
#       poss_id off_team def_team  poss_time  oncourt_id   play_type off_def  \
# id
# 1219        1      LAL      GSW        720           1  Rim Gather     OFF
# 1227        3      LAL      GSW        694           1  Initiation     OFF
#
#        player_type        player_name  player_nba_id  play_clock  sequence_id  \
# id
# 1219  Ball-Handler     DeAndre Jordan       201599.0         716            1
# 1227  Ball-Handler  Russell Westbrook       201566.0         689            3
#
#       play_id       result_id   seq_result_id               play_zone  \
# id
# 1219        2  0022100002_1_1  0022100002_1_1                     Rim
# 1227        6             NaN  0022100002_1_3  Mid-Left Above Break 3
#
#      last_updated_time
# id
# 1219           26:31.2
# 1227           26:31.2

# %% [markdown]
# ## 1. Model & CV

# %%
game_data_master['points'].fillna(0, inplace= True)

# %%
game_data_master = game_data_master.loc[(game_data_master['season_type'] == 'Playoffs')]

# %%
game_data_master = game_data_master.loc[(game_data_master['player_name'] == 'Kevon Looney')]

# %%
game_data_master = game_data_master.loc[
                                         (game_data_master['result_type'] == 'Face-Up') |
                                         (game_data_master['result_type'] == 'Layup') |
                                         (game_data_master['result_type'] == 'Floater') |
                                         (game_data_master['result_type'] == '1-2D Pull-Up') |
                                         (game_data_master['result_type'] == 'Off-Movement') |
                                         (game_data_master['result_type'] == 'Catch & Shoot') |
                                         (game_data_master['result_type'] == 'Off-Lob / Tip') |
                                         (game_data_master['result_type'] == '3+D Pull-Up') |
                                         (game_data_master['result_type'] == 'Take Side') |
                                         (game_data_master['result_type'] == 'Post Fade') |
                                         (game_data_master['result_type'] == 'Hook') |
                                         #(game_data_master['result_type'] == 'Putback') |
                                         (game_data_master['result_type'] == 'Leaner') |
                                         (game_data_master['result_type'] == 'PU Fade') |
                                         (game_data_master['result_type'] == 'Dunk')
                                       ]

# %%
group = game_data_master.groupby('result_type')
game_data_master = group.filter(lambda x: len(x) > 10) 
display(game_data_master['result_type'].value_counts())


group = game_data_master.groupby('result_contest')
game_data_master = group.filter(lambda x: len(x) > 10) 
game_data_master = game_data_master.loc[ (game_data_master['result_contest'] != 'Fouled') &
                                         (game_data_master['result_contest'] != 'Block') &
                                         (game_data_master['result_contest'] != 'Alter') ]

display(game_data_master['result_contest'].value_counts())

group = game_data_master.groupby('result_zone')
game_data_master = group.filter(lambda x: len(x) > 10) 
display(game_data_master['result_zone'].value_counts())


group = game_data_master.groupby('points')
game_data_master = group.filter(lambda x: len(x) > 10) 
display(game_data_master['points'].value_counts())
# Out:
# Layup            71
# Catch & Shoot    31
# Dunk             20
# Off-Movement     16
# Off-Lob / Tip    13
# 1-2D Pull-Up     11
# Name: result_type, dtype: int64
# Open       58
# Average    47
# Plus       16
# Name: result_contest, dtype: int64
# Rim                        69
# Mid-Right Above Break 3    17
# Right Above Break 3        12
# Name: result_zone, dtype: int64
# 2.0    56
# 0.0    30
# 3.0    12
# Name: points, dtype: int64

# %%
targets = ['points']

attributes = [  
                'player_name',
                'result_type',
                'result_contest',
                'result_zone',
            ]

# %%
from sklearn.model_selection import train_test_split

X = pd.get_dummies(game_data_master[attributes])
y = game_data_master[targets]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.20, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, f1_score, auc

C_grid = [1E-5,1E-4,1E-3,1E-2,1E-1,1E0]

# %%
# group / ensemble of models
estimator = []
estimator.append(('LR1', 
                  LogisticRegressionCV(solver ='lbfgs', 
                                     multi_class ='ovr',
                                     Cs = C_grid, 
                                     random_state=69,
                                     max_iter = 10000)))
estimator.append(('LR2', 
                  LogisticRegressionCV(solver ='lbfgs', 
                                     multi_class ='auto',
                                     Cs = C_grid, 
                                     random_state=420, 
                                     max_iter = 10000)))
estimator.append(('LR3', 
                  LogisticRegressionCV(solver ='lbfgs', 
                                     multi_class ='ovr',
                                     Cs = C_grid, 
                                     random_state=0,
                                     max_iter = 10000)))
estimator.append(('LR4', 
                  LogisticRegressionCV(solver ='lbfgs', 
                                     multi_class ='multinomial', 
                                     Cs = C_grid, 
                                     random_state=9876756,
                                     max_iter = 10000)))
estimator.append(('LR5', 
                  LogisticRegressionCV(solver ='lbfgs', 
                                     multi_class ='multinomial',
                                     Cs = C_grid, 
                                     random_state=345,
                                     max_iter = 10000)))

# %%
# Voting Classifier with hard voting
vot_soft = VotingClassifier(estimators = estimator, voting ='soft')
vot_soft.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('LR1',
#                               LogisticRegressionCV(Cs=[1e-05, 0.0001, 0.001,
#                                                        0.01, 0.1, 1.0],
#                                                    max_iter=10000,
#                                                    multi_class='ovr',
#                                                    random_state=69)),
#                              ('LR2',
#                               LogisticRegressionCV(Cs=[1e-05, 0.0001, 0.001,
#                                                        0.01, 0.1, 1.0],
#                                                    max_iter=10000,
#                                                    random_state=420)),
#                              ('LR3',
#                               LogisticRegressionCV(Cs=[1e-05, 0.0001, 0.001,
#                                                        0.01, 0.1, 1.0],
#                                                    max_iter=10000,
#                                                    multi_class='ovr',
#                                                    random_state=0)),
#                              ('LR4',
#                               LogisticRegressionCV(Cs=[1e-05, 0.0001, 0.001,
#                                                        0.01, 0.1, 1.0],
#                                                    max_iter=10000,
#                                                    multi_class='multinomial',
#                                                    random_state=9876756)),
#                              ('LR5',
#                               LogisticRegressionCV(Cs=[1e-05, 0.0001, 0.001,
#                                                        0.01, 0.1, 1.0],
#                                                    max_iter=10000,
#                                                    multi_class='multinomial',
#                                                    random_state=345))],
#                  voting='soft')

# %%
_accuracy_score = np.average(cross_val_score(vot_soft, X_train, y_train, cv=4, scoring="accuracy")) # Avg Cross val score
_f1_score = np.average(cross_val_score(vot_soft, X_train, y_train, cv=4, scoring="f1_weighted")) # Avg Cross val score

# %%
_accuracy_score, _f1_score #, _roc_auc_score, , _auc
# Out:
# (0.6947916666666667, 0.627782346491228)

# %%
log_reg = LogisticRegression(multi_class="multinomial", solver="lbfgs", penalty="l2", C = 1.0, random_state=0, max_iter=10000)

np.average(cross_val_score(log_reg, X_train, y_train, cv=4, scoring="accuracy")) # Avg Cross val score

#f1_weighted = weighted f1 by class instances
# Out:
# 0.7260416666666667

# %% [markdown]
# ## 2. Predictions

# %% [markdown]
# In order to get the correct number of columns for the one hot encoder (pd.get_dummies()), we must add it to the end of the
# game data then take the one hot. This ensures that there are the correct number of columns from the one hot.

# %% [markdown]
# ### Scenarios

# %%
game_data_master['result_type'].unique()
# Out:
# array(['Layup', '1-2D Pull-Up', 'Catch & Shoot', 'Off-Movement',
#        'Off-Lob / Tip', 'Dunk'], dtype=object)

# %%
predict_series = []

for player in  game_data_master['player_name'].unique():
    for result in game_data_master['result_type'].unique():
        for contest in game_data_master['result_contest'].unique():
            for zone in game_data_master['result_zone'].unique():
                predict_series.append({
                    'player_name': player,
                    'result_type': result,
                    'result_contest': contest,
                    'result_zone': zone
                       })

predict_series = pd.DataFrame(predict_series)

# %%
predict_series.head()
# Out:
#     player_name result_type result_contest              result_zone
# 0  Kevon Looney       Layup        Average                      Rim
# 1  Kevon Looney       Layup        Average  Mid-Right Above Break 3
# 2  Kevon Looney       Layup        Average      Right Above Break 3
# 3  Kevon Looney       Layup           Open                      Rim
# 4  Kevon Looney       Layup           Open  Mid-Right Above Break 3

# %%
predict_probs = pd.DataFrame()

for i in range(len(predict_series)):

    scenario = predict_series.iloc[i]
    scenario = pd.DataFrame(scenario).transpose()

    # New DF
    game_data_master_predict = game_data_master    


    ## Append to end of master df
    game_data_master_predict = pd.concat([game_data_master_predict, scenario]) 



    ## Filter out the unimportant columns
    game_data_master_predict = game_data_master_predict[attributes]


    ## one hot encode
    game_data_master_predict = pd.get_dummies(game_data_master_predict)



    ## Get the last entity (the predict_series)
    predicts = game_data_master_predict.iloc[-1]

    ## Turn it into a DataFrame
    predicts = pd.DataFrame(predicts) 

    ## Transpose so that it is 2d array
    predicts = predicts.transpose() 

    probs = pd.DataFrame(vot_soft.predict_proba(predicts))


    output = scenario.to_dict(orient='records')[0] | probs.to_dict(orient='records')[0]

    predict_probs = predict_probs.append(output, ignore_index= True)

# %%
predict_probs.rename(columns= {0: '0 pts', 
                      1: '2 pts',
                      2: '3 pts'
                     }, inplace= True)
predict_probs
# Out:
#      player_name    result_type result_contest              result_zone  \
# 0   Kevon Looney          Layup        Average                      Rim
# 1   Kevon Looney          Layup        Average  Mid-Right Above Break 3
# 2   Kevon Looney          Layup        Average      Right Above Break 3
# 3   Kevon Looney          Layup           Open                      Rim
# 4   Kevon Looney          Layup           Open  Mid-Right Above Break 3
# 5   Kevon Looney          Layup           Open      Right Above Break 3
# 6   Kevon Looney          Layup           Plus                      Rim
# 7   Kevon Looney          Layup           Plus  Mid-Right Above Break 3
# 8   Kevon Looney          Layup           Plus      Right Above Break 3
# 9   Kevon Looney   1-2D Pull-Up        Average                      Rim
# 10  Kevon Looney   1-2D Pull-Up        Average  Mid-Right Above Break 3
# 11  Kevon Looney   1-2D Pull-Up        Average      Right Above Break 3
# 12  Kevon Looney   1-2D Pull-Up           Open                      Rim
# 13  Kevon Looney   1-2D Pull-Up           Open  Mid-Right Above Break 3
# 14  Kevon Looney   1-2D Pull-Up           Open      Right Above Break 3
# 15  Kevon Looney   1-2D Pull-Up           Plus                      Rim
# 16  Kevon Looney   1-2D Pull-Up           Plus  Mid-Right Above Break 3
# 17  Kevon Looney   1-2D Pull-Up           Plus      Right Above Break 3
# 18  Kevon Looney  Catch & Shoot        Average                      Rim
# 19  Kevon Looney  Catch & Shoot        Average  Mid-Right Above Break 3
# 20  Kevon Looney  Catch & Shoot        Average      Right Above Break 3
# 21  Kevon Looney  Catch & Shoot           Open                      Rim
# 22  Kevon Looney  Catch & Shoot           Open  Mid-Right Above Break 3
# 23  Kevon Looney  Catch & Shoot           Open      Right Above Break 3
# 24  Kevon Looney  Catch & Shoot           Plus                      Rim
# 25  Kevon Looney  Catch & Shoot           Plus  Mid-Right Above Break 3
# 26  Kevon Looney  Catch & Shoot           Plus      Right Above Break 3
# 27  Kevon Looney   Off-Movement        Average                      Rim
# 28  Kevon Looney   Off-Movement        Average  Mid-Right Above Break 3
# 29  Kevon Looney   Off-Movement        Average      Right Above Break 3
# 30  Kevon Looney   Off-Movement           Open                      Rim
# 31  Kevon Looney   Off-Movement           Open  Mid-Right Above Break 3
# 32  Kevon Looney   Off-Movement           Open      Right Above Break 3
# 33  Kevon Looney   Off-Movement           Plus                      Rim
# 34  Kevon Looney   Off-Movement           Plus  Mid-Right Above Break 3
# 35  Kevon Looney   Off-Movement           Plus      Right Above Break 3
# 36  Kevon Looney  Off-Lob / Tip        Average                      Rim
# 37  Kevon Looney  Off-Lob / Tip        Average  Mid-Right Above Break 3
# 38  Kevon Looney  Off-Lob / Tip        Average      Right Above Break 3
# 39  Kevon Looney  Off-Lob / Tip           Open                      Rim
# 40  Kevon Looney  Off-Lob / Tip           Open  Mid-Right Above Break 3
# 41  Kevon Looney  Off-Lob / Tip           Open      Right Above Break 3
# 42  Kevon Looney  Off-Lob / Tip           Plus                      Rim
# 43  Kevon Looney  Off-Lob / Tip           Plus  Mid-Right Above Break 3
# 44  Kevon Looney  Off-Lob / Tip           Plus      Right Above Break 3
# 45  Kevon Looney           Dunk        Average                      Rim
# 46  Kevon Looney           Dunk        Average  Mid-Right Above Break 3
# 47  Kevon Looney           Dunk        Average      Right Above Break 3
# 48  Kevon Looney           Dunk           Open                      Rim
# 49  Kevon Looney           Dunk           Open  Mid-Right Above Break 3
# 50  Kevon Looney           Dunk           Open      Right Above Break 3
# 51  Kevon Looney           Dunk           Plus                      Rim
# 52  Kevon Looney           Dunk           Plus  Mid-Right Above Break 3
# 53  Kevon Looney           Dunk           Plus      Right Above Break 3
#
#        0 pts     2 pts     3 pts
# 0   0.230306  0.668899  0.100795
# 1   0.428893  0.395889  0.175218
# 2   0.467494  0.387816  0.144690
# 3   0.131411  0.760204  0.108386
# 4   0.284869  0.509915  0.205216
# 5   0.326856  0.501768  0.171376
# 6   0.163397  0.728134  0.108469
# 7   0.336698  0.464055  0.199247
# 8   0.379739  0.454866  0.165395
# 9   0.297415  0.576367  0.126218
# 10  0.490262  0.298197  0.211540
# 11  0.530804  0.294178  0.175018
# 12  0.177953  0.682652  0.139395
# 13  0.343986  0.401522  0.254492
# 14  0.392466  0.395061  0.212473
# 15  0.217816  0.643704  0.138481
# 16  0.398091  0.357928  0.243981
# 17  0.445533  0.351684  0.202783
# 18  0.378976  0.492718  0.128307
# 19  0.556720  0.235666  0.207614
# 20  0.592489  0.235193  0.172318
# 21  0.243622  0.609319  0.147059
# 22  0.424139  0.321920  0.253941
# 23  0.470883  0.317651  0.211466
# 24  0.291916  0.564120  0.143964
# 25  0.475053  0.283705  0.241242
# 26  0.518447  0.280987  0.200566
# 27  0.336676  0.533917  0.129408
# 28  0.521421  0.264624  0.213955
# 29  0.559470  0.263054  0.177476
# 30  0.207970  0.646386  0.145643
# 31  0.381880  0.358999  0.259122
# 32  0.429979  0.353834  0.216187
# 33  0.252389  0.603951  0.143660
# 34  0.434678  0.317962  0.247360
# 35  0.480259  0.313940  0.205800
# 36  0.304233  0.590113  0.105654
# 37  0.500306  0.319464  0.180230
# 38  0.534553  0.316266  0.149181
# 39  0.184131  0.698112  0.117756
# 40  0.361757  0.422546  0.215696
# 41  0.405322  0.415605  0.179074
# 42  0.225425  0.658168  0.116406
# 43  0.414363  0.378546  0.207091
# 44  0.455723  0.372756  0.171521
# 45  0.218955  0.675397  0.105649
# 46  0.414278  0.400591  0.185131
# 47  0.455018  0.392082  0.152899
# 48  0.124435  0.762980  0.112584
# 49  0.270244  0.514066  0.215690
# 50  0.312178  0.507137  0.180685
# 51  0.154670  0.732283  0.113047
# 52  0.321133  0.468935  0.209932
# 53  0.365093  0.460237  0.174670

# %%
#%cd ../
predict_probs.to_csv(r'./Looney_data/Looney_playoffs.csv')
